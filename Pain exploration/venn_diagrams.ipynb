# %% [markdown]
# From https://www.badgrammargoodsyntax.com/compbio/2017/10/29/compbio-012-making-venn-diagrams-the-right-way-using-python

# %%
import pandas as pd
import matplotlib
import sys
import os

# %matplotlib inline
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

# %%
# to import files from googledrive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
lst_lit = 'gdrive/My Drive/pain_lists/lists for venn/literature.xlsx'
lst_ont = 'gdrive/My Drive/pain_lists/lists for venn/ontology.xlsx'
lst_emb = 'gdrive/My Drive/pain_lists/lists for venn/embedding.xlsx'

# %%
venn3([set(lst_lit), set(lst_ont), set(lst_emb)], set_labels = ('Literature', 'Ontology', 'Embeddings'))
plt.title('Comparison of different sources \n')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib_venn/_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")
# Text(0.5, 1.0, 'Comparison of different sources \n')

# %%
from matplotlib_venn import venn3_unweighted 


venn3_unweighted([set(lst_lit), set(lst_ont), set(lst_emb)], set_labels = ('Literature', 'Ontology', 'Embeddings'))
plt.title('Comparison of different sources \n')
# Out:
# Text(0.5, 1.0, 'Comparison of different sources \n')

# %%
lst_mimic = 'gdrive/My Drive/pain_lists/lists for venn/mimic.xlsx'
lst_ont = 'gdrive/My Drive/pain_lists/lists for venn/CRIS.xlsx'
lst_emb = 'gdrive/My Drive/pain_lists/lists for venn/pubmed.xlsx'

# %%
venn3([set(lst_lit), set(lst_ont), set(lst_emb)], set_labels = ('MIMIC', 'CRIS', 'PubMed'))
plt.title('Comparison of different embeddings \n')
# Out:
# Text(0.5, 1.0, 'Comparison of different embeddings \n')

# %%
venn3_unweighted([set(lst_lit), set(lst_ont), set(lst_emb)], set_labels = ('MIMIC', 'CRIS', 'PubMed'))
plt.title('Comparison of different embeddings \n')
# Out:
# Text(0.5, 1.0, 'Comparison of different embeddings \n')

# %%
lst_icd = 'gdrive/My Drive/pain_lists/lists for venn/ICD10.xlsx'
lst_ont = 'gdrive/My Drive/pain_lists/lists for venn/SNOMED.xlsx'
lst_emb = 'gdrive/My Drive/pain_lists/lists for venn/UMLS.xlsx'

# %%
venn3([set(lst_lit), set(lst_ont), set(lst_emb)], set_labels = ('ICD-10', 'SNOMED-CT', 'UMLS'))
plt.title('Comparison of different ontologies \n')
# Out:
# Text(0.5, 1.0, 'Comparison of different ontologies \n')

# %%
venn3_unweighted([set(lst_lit), set(lst_ont), set(lst_emb)], set_labels = ('ICD-10', 'SNOMED-CT', 'UMLS'))
plt.title('Comparison of different ontologies \n')
# Out:
# Text(0.5, 1.0, 'Comparison of different ontologies \n')
