# %%
# script from aurelie

# %%
import sys
import os
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
# location of embedding file - MIMIC-III
emb_file='./mimic_model_non_alpha_size100'

# %%
# location of embedding file - MIMIC-III
emb_file='./mimic_model_non_alpha_bigram_size400_v1'

# %%
# location of embedding file - MIMIC-III
emb_file='./noteevents_clean_fasttext_win10_min5.dat'

# %%
# load embedding file
try:
    model = Word2Vec.load(emb_file)
except:
    model = KeyedVectors.load(emb_file, mmap='r')

# %%
# 15 words most similar to pain
model.wv.most_similar('pain', topn=15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-711302a15034> in <module>
#       1 # 15 words most similar to pain
# ----> 2 model.wv.most_similar('pain', topn=15)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
# ...

# %%
# similarity between pain and ache
model.wv.similarity('pain', 'ache')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3a056dc7f41f> in <module>
#       1 # similarity between pain and ache
# ----> 2 model.wv.similarity('pain', 'ache')
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     972
#     973         """
# --> 974         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     975
#     976     def n_similarity(self, ws1, ws2):
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ...

# %%
# 15 words most similar to chronic
model.wv.most_similar('chronic', topn=15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3abb90e6b793> in <module>
#       1 # 15 words most similar to chronic
# ----> 2 model.wv.most_similar('chronic', topn=15)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
# ...

# %%
# similarity between chronic and pain
model.wv.similarity('chronic', 'pain')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d303ae463453> in <module>
#       1 # similarity between chronic and pain
# ----> 2 model.wv.similarity('chronic', 'pain')
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     972
#     973         """
# --> 974         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     975
#     976     def n_similarity(self, ws1, ws2):
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ...

# %%
# 15 words most similar to persistent
model.wv.most_similar('persistent', topn=15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6c2e553058c1> in <module>
#       1 # 15 words most similar to persistent
# ----> 2 model.wv.most_similar('persistent', topn=15)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
# ...

# %%
# similarity between persistent and pain
model.wv.similarity('persistent', 'pain')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-de3bc5be7247> in <module>
#       1 # similarity between persistent and pain
# ----> 2 model.wv.similarity('persistent', 'pain')
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     972
#     973         """
# --> 974         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     975
#     976     def n_similarity(self, ws1, ws2):
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
# ...

# %%
# similarity between persistent and chronic
model.wv.similarity('persistent', 'chronic')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-cb5d4f6f65ed> in <module>
#       1 # similarity between persistent and chronic
# ----> 2 model.wv.similarity('persistent', 'chronic')
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     972
#     973         """
# --> 974         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     975
#     976     def n_similarity(self, ws1, ws2):
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
# ...

# %%
# 15 words most similar to chronic pain
model.wv.most_similar('chronic_pain', topn=15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-ea5e1a5e5e52> in <module>
#       1 # 15 words most similar to chronic pain
# ----> 2 model.wv.most_similar('chronic_pain', topn=15)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
# ...
